# %%
# ── run this ONCE at the top of every demo notebook ────────────────────
import sys, pathlib, os

# 1) current working dir where the kernel started
here = pathlib.Path(os.getcwd()).resolve()

# 2) walk upward until we find the "src" folder
while here != here.root and not (here / "src").exists():
    here = here.parent

# 3) append that folder to sys.path  (only once)
if str(here) not in sys.path:
    sys.path.append(str(here))

print("✓ added to PYTHONPATH:", here)
# ───────────────────────────────────────────────────────────────────────
# Out:
# ✓ added to PYTHONPATH: C:\Users\tgati\molder-rl

# %%
# 03_xgb_demo.ipynb
# Demo: XGBoost quality alarm on 30 random test shots

import pathlib as pl
import numpy as np
import pandas as pd
import joblib
from src.models.xgb_quality_wrapper import predict_fail, prob_fail

# %%
TEST_PARQ = pl.Path(r"C:/Users/tgati/molder-rl/data/interim/features_test.parquet")
df_test   = pd.read_parquet(TEST_PARQ)

np.random.seed(42)
demo_idx  = np.random.choice(df_test.index, 30, replace=False)
demo_df   = df_test.loc[demo_idx].copy().reset_index(drop=True)

# keep the ground-truth label for comparison
gt_labels = demo_df.pop("label").values
demo_df.head()
# Out:
#    cycle_time  filling_time  plasticizing_time  clamp_close_time  \
# 0   61.779999          0.93          12.910000              6.81
# 1   59.459999          4.39          16.799999              7.12
# 2   59.480000          4.39          16.820000              7.13
# 3   59.439999          4.38          16.820000              7.12
# 4   59.520000          4.46          16.889999              7.13
#
#    max_inj_pressure  max_back_pressure  avg_back_pressure  max_screw_rpm  \
# 0        142.399994          55.500000          60.500000      30.900000
# 1        141.800003          37.500000          59.299999      30.700001
# 2        141.699997          37.400002          59.200001      30.600000
# 3        141.699997          37.099998          59.099998      30.400000
# 4        142.000000          38.099998          59.599998      30.700001
#
#    avg_screw_rpm  max_inj_speed  cushion_error  switch_over_error  \
# 0     290.399994     128.399994     649.270020              -15.0
# 1      29.200001      56.000000     648.440002              -15.0
# 2      29.200001      56.000000     648.440002              -15.0
# 3      29.200001      56.200001     648.440002              -15.0
# 4      29.200001      55.299999     648.440002              -15.0
#
#    barrel_temp_avg  hopper_temp  mold_temp_avg  delta_mold_temp  outlier_flag
# 0       232.942858    65.500000       3.900000        24.000000             1
# 1       226.185713    67.099998       3.541667        21.799999             0
# 2       225.914287    66.599998       3.591667        22.100000             0
# 3       225.985718    66.300003       3.733333        23.000000             1
# 4       225.985711    68.000000       3.900000        24.100000             0

# %%
preds = []
probs = []

for row in demo_df.to_numpy(dtype=np.float32):
    p = prob_fail(row)
    probs.append(p)
    preds.append(predict_fail(row))

demo_df["P_fail"]   = np.round(probs, 3)
demo_df["Pred_NG"]  = preds          # 1 = NG alarm
demo_df["True_NG"]  = gt_labels

# %%
def color_row(row):
    if row["True_NG"] == 1:
        return ['background-color: gold'] * len(row)  # actual defect
    if row["Pred_NG"] == 1:
        return ['background-color: salmon'] * len(row)  # false alarm
    return [''] * len(row)   # OK shot

styled = (demo_df[["P_fail", "Pred_NG", "True_NG"]]
          .style
          .apply(color_row, axis=1)
          .format({"P_fail": "{:.3f}"}))
styled
# Out:
# <style type="text/css">
# #T_33638_row0_col0, #T_33638_row0_col1, #T_33638_row0_col2, #T_33638_row1_col0, #T_33638_row1_col1, #T_33638_row1_col2, #T_33638_row2_col0, #T_33638_row2_col1, #T_33638_row2_col2, #T_33638_row3_col0, #T_33638_row3_col1, #T_33638_row3_col2, #T_33638_row4_col0, #T_33638_row4_col1, #T_33638_row4_col2, #T_33638_row5_col0, #T_33638_row5_col1, #T_33638_row5_col2, #T_33638_row6_col0, #T_33638_row6_col1, #T_33638_row6_col2, #T_33638_row7_col0, #T_33638_row7_col1, #T_33638_row7_col2, #T_33638_row8_col0, #T_33638_row8_col1, #T_33638_row8_col2, #T_33638_row9_col0, #T_33638_row9_col1, #T_33638_row9_col2, #T_33638_row10_col0, #T_33638_row10_col1, #T_33638_row10_col2, #T_33638_row11_col0, #T_33638_row11_col1, #T_33638_row11_col2, #T_33638_row12_col0, #T_33638_row12_col1, #T_33638_row12_col2, #T_33638_row13_col0, #T_33638_row13_col1, #T_33638_row13_col2, #T_33638_row14_col0, #T_33638_row14_col1, #T_33638_row14_col2, #T_33638_row15_col0, #T_33638_row15_col1, #T_33638_row15_col2, #T_33638_row16_col0, #T_33638_row16_col1, #T_33638_row16_col2, #T_33638_row17_col0, #T_33638_row17_col1, #T_33638_row17_col2, #T_33638_row18_col0, #T_33638_row18_col1, #T_33638_row18_col2, #T_33638_row19_col0, #T_33638_row19_col1, #T_33638_row19_col2, #T_33638_row20_col0, #T_33638_row20_col1, #T_33638_row20_col2, #T_33638_row21_col0, #T_33638_row21_col1, #T_33638_row21_col2, #T_33638_row22_col0, #T_33638_row22_col1, #T_33638_row22_col2, #T_33638_row23_col0, #T_33638_row23_col1, #T_33638_row23_col2, #T_33638_row24_col0, #T_33638_row24_col1, #T_33638_row24_col2, #T_33638_row25_col0, #T_33638_row25_col1, #T_33638_row25_col2, #T_33638_row26_col0, #T_33638_row26_col1, #T_33638_row26_col2, #T_33638_row27_col0, #T_33638_row27_col1, #T_33638_row27_col2, #T_33638_row28_col0, #T_33638_row28_col1, #T_33638_row28_col2, #T_33638_row29_col0, #T_33638_row29_col1, #T_33638_row29_col2 {
#   background-color: salmon;
# }
# </style>
# <table id="T_33638">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33638_level0_col0" class="col_heading level0 col0" >P_fail</th>
#       <th id="T_33638_level0_col1" class="col_heading level0 col1" >Pred_NG</th>
#       <th id="T_33638_level0_col2" class="col_heading level0 col2" >True_NG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33638_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33638_row0_col0" class="data row0 col0" >0.073</td>
#       <td id="T_33638_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_33638_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33638_row1_col0" class="data row1 col0" >0.073</td>
#       <td id="T_33638_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_33638_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_33638_row2_col0" class="data row2 col0" >0.073</td>
#       <td id="T_33638_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_33638_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_33638_row3_col0" class="data row3 col0" >0.073</td>
#       <td id="T_33638_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_33638_row3_col2" class="data row3 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_33638_row4_col0" class="data row4 col0" >0.073</td>
#       <td id="T_33638_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_33638_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_33638_row5_col0" class="data row5 col0" >0.073</td>
#       <td id="T_33638_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_33638_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_33638_row6_col0" class="data row6 col0" >0.073</td>
#       <td id="T_33638_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_33638_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_33638_row7_col0" class="data row7 col0" >0.073</td>
#       <td id="T_33638_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_33638_row7_col2" class="data row7 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_33638_row8_col0" class="data row8 col0" >0.073</td>
#       <td id="T_33638_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_33638_row8_col2" class="data row8 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_33638_row9_col0" class="data row9 col0" >0.073</td>
#       <td id="T_33638_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_33638_row9_col2" class="data row9 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_33638_row10_col0" class="data row10 col0" >0.073</td>
#       <td id="T_33638_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_33638_row10_col2" class="data row10 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_33638_row11_col0" class="data row11 col0" >0.073</td>
#       <td id="T_33638_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_33638_row11_col2" class="data row11 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_33638_row12_col0" class="data row12 col0" >0.073</td>
#       <td id="T_33638_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_33638_row12_col2" class="data row12 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_33638_row13_col0" class="data row13 col0" >0.073</td>
#       <td id="T_33638_row13_col1" class="data row13 col1" >1</td>
#       <td id="T_33638_row13_col2" class="data row13 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_33638_row14_col0" class="data row14 col0" >0.073</td>
#       <td id="T_33638_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_33638_row14_col2" class="data row14 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_33638_row15_col0" class="data row15 col0" >0.073</td>
#       <td id="T_33638_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_33638_row15_col2" class="data row15 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_33638_row16_col0" class="data row16 col0" >0.073</td>
#       <td id="T_33638_row16_col1" class="data row16 col1" >1</td>
#       <td id="T_33638_row16_col2" class="data row16 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_33638_row17_col0" class="data row17 col0" >0.073</td>
#       <td id="T_33638_row17_col1" class="data row17 col1" >1</td>
#       <td id="T_33638_row17_col2" class="data row17 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_33638_row18_col0" class="data row18 col0" >0.073</td>
#       <td id="T_33638_row18_col1" class="data row18 col1" >1</td>
#       <td id="T_33638_row18_col2" class="data row18 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_33638_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_33638_row19_col0" class="

# %%
TP = ((demo_df["Pred_NG"] == 1) & (demo_df["True_NG"] == 1)).sum()
FP = ((demo_df["Pred_NG"] == 1) & (demo_df["True_NG"] == 0)).sum()
FN = ((demo_df["Pred_NG"] == 0) & (demo_df["True_NG"] == 1)).sum()

print(f"Caught defects  (TP): {TP}")
print(f"False alarms   (FP): {FP}")
print(f"Missed defects (FN): {FN}")
# Out:
# Caught defects  (TP): 0
# False alarms   (FP): 30
# Missed defects (FN): 0
